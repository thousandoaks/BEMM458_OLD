# %% [markdown]
# # Lab 4. My first data science project

# %% [markdown]
# ## In this lab you will apply the concepts and techniques developed in previous sessions. You are expected to work on the assignments on your own DURING the duration of the lab.
# ## You are expected to submit the code developed as well as a brief description of your findings and insights for each assigment AT THE END of the lab.
#
# ## This lab represents 20% of the total marking of the module¶

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
### Let's load the gapminder dataset
gapminder = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
gapminder.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165877
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %% [markdown]
# ### Assignment 4.1. Find countries in which lifeExpectancy is lower than 40 AND population is larger than 50 million

# %%
populationFilter=gapminder['pop']>50000000

# %%
gapminder[populationFilter]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 97    Bangladesh      Asia  1957   39.348  51365468   661.637458
# 98    Bangladesh      Asia  1962   41.216  56839289   686.341554
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 100   Bangladesh      Asia  1972   45.252  70759295   630.233627
# 101   Bangladesh      Asia  1977   46.923  80428306   659.877232
# ...          ...       ...   ...      ...       ...          ...
# 1651     Vietnam      Asia  1987   62.820  62826491   820.799445
# 1652     Vietnam      Asia  1992   67.662  69940728   989.023149
# 1653     Vietnam      Asia  1997   70.672  76048996  1385.896769
# 1654     Vietnam      Asia  2002   73.017  80908147  1764.456677
# 1655     Vietnam      Asia  2007   74.249  85262356  2441.576404
#
# [190 rows x 6 columns]

# %%
lifeExpFilter=gapminder['lifeExp']<=40

# %%
gapminder[populationFilter & lifeExpFilter]
# Out:
#         country continent  year  lifeExp        pop   gdpPercap
# 97   Bangladesh      Asia  1957   39.348   51365468  661.637458
# 696       India      Asia  1952   37.373  372000000  546.565749
# 708   Indonesia      Asia  1952   37.468   82052000  749.681655
# 709   Indonesia      Asia  1957   39.918   90124000  858.900271

# %% [markdown]
# ### Assignment 4.2. Order the gapminder dataset by life expectancy (descending order)
#
# #### Hint: look on the pandas documentation how to sort values (sort_values() function)

# %%
gapminder.sort_values(by='lifeExp',ascending=False)
# Out:
#                country continent  year  lifeExp        pop     gdpPercap
# 803              Japan      Asia  2007   82.603  127467972  31656.068060
# 671   Hong Kong, China      Asia  2007   82.208    6980412  39724.978670
# 802              Japan      Asia  2002   82.000  127065841  28604.591900
# 695            Iceland    Europe  2007   81.757     301931  36180.789190
# 1487       Switzerland    Europe  2007   81.701    7554661  37506.419070
# ...                ...       ...   ...      ...        ...           ...
# 1344      Sierra Leone    Africa  1952   30.331    2143249    879.787736
# 36              Angola    Africa  1952   30.015    4232095   3520.610273
# 552             Gambia    Africa  1952   30.000     284320    485.230659
# 0          Afghanistan      Asia  1952   28.801    8425333    779.445314
# 1292            Rwanda    Africa  1992   23.599    7290203    737.068595
#
# [1704 rows x 6 columns]

# %% [markdown]
# ### Assignment 4.3. Plot the evolution of life expectancy, population and GDP per capita of United Kingdom
#
# #### TIP: consider lineplot https://seaborn.pydata.org/generated/seaborn.lineplot.html

# %%
uk=gapminder[gapminder['country']=='United Kingdom']

# %%
uk
# Out:
#              country continent  year  lifeExp       pop     gdpPercap
# 1596  United Kingdom    Europe  1952   69.180  50430000   9979.508487
# 1597  United Kingdom    Europe  1957   70.420  51430000  11283.177950
# 1598  United Kingdom    Europe  1962   70.760  53292000  12477.177070
# 1599  United Kingdom    Europe  1967   71.360  54959000  14142.850890
# 1600  United Kingdom    Europe  1972   72.010  56079000  15895.116410
# 1601  United Kingdom    Europe  1977   72.760  56179000  17428.748460
# 1602  United Kingdom    Europe  1982   74.040  56339704  18232.424520
# 1603  United Kingdom    Europe  1987   75.007  56981620  21664.787670
# 1604  United Kingdom    Europe  1992   76.420  57866349  22705.092540
# 1605  United Kingdom    Europe  1997   77.218  58808266  26074.531360
# 1606  United Kingdom    Europe  2002   78.471  59912431  29478.999190
# 1607  United Kingdom    Europe  2007   79.425  60776238  33203.261280

# %%
sns.lineplot(x="year", y="lifeExp", data=uk)

# %%
sns.lineplot(x="year", y="pop", data=uk)

# %%
sns.lineplot(x="year", y="gdpPercap", data=uk)

# %% [markdown]
# ### Assignment 4.4. Is there any significant relationship between life expectancy and GDP in the UK ?

# %% [markdown]
# ### Tip: have a look at seaborn-based techniques to represent relationships between two variables.
# ### check the following link for alternatives: https://seaborn.pydata.org/tutorial.html

# %%
ax = sns.kdeplot(data=uk['gdpPercap'],data2=uk['lifeExp'],shade=True) # shade will fill in the contours
ax.set_title('Kernel Density Plot of GDP and lifeExpectancy');
ax.set_xlabel('GDPPerCap');

# %%
sns.jointplot("gdpPercap", "lifeExp", data=uk,
                  kind="reg", truncate=False)

# %% [markdown]
# ### Assignment 4.5. Is there any significant relationship between life expectancy and GDP in the UK ?

# %% [markdown]
# ### Tip: have a look at seaborn-based techniques to represent relationships between two variables.
# ### check the following link for alternatives: https://seaborn.pydata.org/tutorial.html

# %%
ax = sns.kdeplot(data=uk['lifeExp'],data2=uk['pop'],shade=True) # shade will fill in the contours
ax.set_title('Kernel Density Plot of lifeExpectancy and population');
ax.set_xlabel('lifeExpectancY');
