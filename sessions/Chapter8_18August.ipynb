# %% [markdown]
# # Session 8. Strings and Text Data

# %% [markdown]
# ## This session will cover:
#
# 1. Subsetting strings
# 2. String methods
# 3. String formatting
# 4. Regular expressions

# %% [markdown]
# # 1. Lets import required libraries

# %%
import re

# %% [markdown]
# # 1. Strings

# %% [markdown]
# ## In Python, a string is simply a series of characters. They are created by a set of opening and matching single or double quotes. For example,

# %%
word = 'grail'
sent = 'a scratch'

# %%
word[0]
# Out:
# 'g'

# %%
sent[6]
# Out:
# 't'

# %%
word[0:3]
# Out:
# 'gra'

# %%
word[-1]
# Out:
# 'l'

# %%
word[-4:]
# Out:
# 'rail'

# %% [markdown]
# # 2. String methods

# %%
sentence='this is a really long string of words'

# %%
sentence.capitalize()
# Out:
# 'This is a really long string of words'

# %%
sentence.count('a')
# Out:
# 2

# %%
sentence.count('i')
# Out:
# 3

# %%
sentence.upper()
# Out:
# 'THIS IS A REALLY LONG STRING OF WORDS'

# %%
sentence.startswith('this')
# Out:
# True

# %%
word.join(sent)
# Out:
# 'agrail grailsgrailcgrailrgrailagrailtgrailcgrailh'

# %% [markdown]
# # 3. Finding patterns

# %%
## This is a regex pattern that matches digits
pattern_digits = '\d+'

# %%
names="13 Jodie Whittaker, John Hurn 12, Peter Capaldi 11, Matt Smith 10, David Tennant 9"

# %%
numbers = re.findall(pattern=pattern_digits, string=names)

# %%
numbers
# Out:
# ['13', '12', '11', '10', '9']

# %%
pattern_words = '\^Jo+'

# %%
words = re.findall(pattern=pattern_words, string=names)

# %%
words
# Out:
# []
